# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahir-MD/FlyRank-Week-01/blob/main/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tahir-MD/FlyRank-Week-01/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# My lane is best described as a scoring and ranking task. Instead of putting every page
# into one fixed category, the goal is to give each page a risk score that reflects how
# likely it is to be declining, and then rank all pages from highest risk to lowest. This
# matches the actual outcome I want, which is an ordered list telling a content team which
# pages to review first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# The thing I would predict is whether a page is declining or not. Since I do not have a
# direct measurement of true business harm for each page, I am using a proxy label instead,
# which is the existing trend direction column in the data. A page marked as down is treated
# as the positive case I want my model to catch early. This label comes from an observed
# pattern in the data rather than a perfect or guaranteed outcome, so it is a proxy, not a
# ground truth measurement of harm.

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd

df = pd.read_csv("/content/content_refresh_anonymized.csv")
df["is_declining"] = (df["trend_direction"] == "down").astype(int)
print(df["is_declining"].value_counts())
# Out:
# is_declining
# 1    10072
# 0     8626
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Success metric
#
# The metric I would defend is Precision at 50, meaning out of the top 50 pages my ranking
# flags as highest risk, how many are actually declining. This is the same metric the
# starter pipeline already uses, and it fits the real world use case well, since a content
# team can only review a limited number of pages at a time. A good result means most of
# those top 50 pages truly need attention, not that the model is right about every single
# page in the whole dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# One row in this slice is one page. Each row carries the traffic and ranking signals for
# that page, along with the proxy label showing whether it is currently declining.

# %%
# This cell is for CODE (numbers, a query, a check).
lane_slice = df[["content_id", "trend_direction", "is_declining", "position_tier",
                  "content_type", "search_volume", "impressions_90d", "ctr", "word_count"]]

print("One row equals one page.")
lane_slice.head(5)
# Out:
# One row equals one page.
#              content_id trend_direction  is_declining position_tier  \
# 0  content_304f48230142            down             1      striking
# 1  content_a1fb4e703a9e            down             1      page_3_5
# 2  content_9aa793d4d895            down             1      page_3_5
# 3  content_331d6c4de07b          stable             0        page_1
# 4  content_d99b7a2d90ca            down             1      page_3_5
#
#       content_type  search_volume  impressions_90d   ctr  word_count
# 0  keyword article           10.0           3803.0  0.76      3221.0
# 1  keyword article           90.0          15320.0  0.05      2481.0
# 2  keyword article            0.0          12581.0  0.09      3515.0
# 3  keyword article           10.0          11751.0  0.49         NaN
# 4  keyword article            0.0          19140.0  0.13      2803.0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A simple fixed rule, like flagging any page with low click through rate, misses how these
# signals interact with each other. For example, a low click through rate might be normal
# for a page sitting in a weak position tier, but concerning for a page sitting in a strong
# position. Content type also changes what a normal click through rate even looks like, as
# shown in week one. Writing a single if statement that accounts for all these overlapping
# conditions at once quickly becomes unreadable and brittle, while a model can weigh several
# signals together and rank pages more reliably.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
